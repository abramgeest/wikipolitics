# %%
import urllib
import requests
import json
import pandas as pd
from pandas import read_sql
import datetime
import matplotlib.pyplot as plt
import os
import numpy as np
from copy import deepcopy
import pymysql as mdb

# %%
numtop=85

# %%
afile="/Users/abramvandergeest/mysql_insightwiki_auth.txt"
a=open(afile)
passwd=a.readline().rstrip()
a.close()
host='localhost'; user='abram.ghost';db='wikidata'
con = mdb.connect(host, user, passwd, db,port=3307)

# %%
#def week_list(base):
#    numdays=7
#    return([base - datetime.timedelta(days=x) for x in range(0, numdays)])

def datefromstr(str):
    return datetime.datetime(int(str[0:4]), int(str[5:7]),int(str[8:]))

str='2015091618'
def date_parse(str):
    year =int(str[:4])
    month=int(str[4:6])
    day=int(str[6:8])
    hour=int(str[8:])
    return datetime.datetime(year,month,day,hour)

def date_parse2(str):
    year =int(str[:4])
    month=int(str[4:6])
    day=int(str[6:8])
    hour=0
    return datetime.datetime(year,month,day,hour)

def datetime2str(t):
    return "%4d%02d%02d%02d"%(t.year,t.month,t.day,t.hour)
    
def gen_feat(into):
    avg=np.average(into)
    #print avg
    maxv= np.max(into)/avg
    minv= np.min(into)/avg
    rmsv= np.std(into)/avg
    difxv=np.max(np.diff(into))/avg
    difnv=np.min(np.diff(into))/avg
    return([maxv,minv,rmsv,difxv,difnv])

# %%
with con:
    curt= con.cursor()
    #sql="SELECT COUNT(*) FROM `topics` "
    
    sql="SELECT `Id`,`topic_label`,`topic_string` FROM `topics`;"
    curt.execute(sql)
    topics=[]
    for topic in curt:
        topics.append(topic)

data={}

df=range(numtop)
with con:
    curt= con.cursor()
    #sql="SELECT COUNT(*) FROM `topics` "
    #curt.execute(sql)
    sql="SELECT `Id`,`topic_label`,`topic_string` FROM `topics`;"
    curt.execute(sql)
    for row in curt:
        #cur = con.cursor()
        #sql='''SELECT `page_views`.`count` AS `vc`,`page_views`.`date` AS `vd` 
        #     FROM `topics` INNER JOIN `page_views` on `topics`.`ID` = `page_views`.`topic_id` 
        #     WHERE `topics`.`id`=%s '''
        sql='''SELECT `page_views`.`dateonly` AS `vd`, AVG(`page_views`.`count`) AS `vc`, `topics`.`topic_label`,`topics`.`topic_string` 
            FROM `topics` INNER JOIN `page_views` ON `topics`.`ID` = `page_views`.`topic_id` 
            WHERE `topic_id`=%s GROUP BY `page_views`.`dateonly`   '''
        #print sql
        
        data[row[1]]=read_sql(sql, con,params=[row[0]])
        df[row[0]]=data[row[1]]
        #data[row[1]]=df[len(df)-1][1]

topicdata=df

# %%
i=80
for i in xrange(0,84):
    xmin=datetime.datetime(2015,3,1)
    xmax=datetime.datetime(2015,10,1)
    ymin=0;ymax=40;
    # %matplotlib inline
    print topics[i][2].rsplit()
    ilabel=topics[i][2].rsplit()[0]
    top=topics[i][1]#topic to consider for now
    print top,i
    data[top]['date']=map(lambda x:date_parse2(x),data[top]['vd'] )
    #df[1][['tl','vd','vc']]
    plt.plot_date(data[top][['date']].values,data[top][['vc']].values)
    plt.xlim([xmin,xmax])
    plt.show()
# Out:
# ['Joe', 'Biden']
# joebiden 0
# ['Lincoln', 'Chafee']
# lincolnchafee 1
# ['Hillary', 'Clinton']
# hillaryclinton 2
# ['Martin', 'O', 'Malley']
# martinomalley 3
# ['Bernie', 'Sanders']
# berniesanders 4
# ['Jim', 'Webb']
# jimwebb 5
# ['Jeb', 'Bush']
# jebbush 6
# ['Ben', 'Carson']
# bencarson 7
# ['Chris', 'Christie']
# chrischristie 8
# ['Ted', 'Cruz']
# tedcruz 9
# ['Carly', 'Fiorina']
# carlyfiorina 10
# ['Jim', 'Gilmore']
# jimgilmore 11
# ['Lindsey', 'Graham']
# lindseygraham 12
# ['Mike', 'Huckabee']
# mikehuckabee 13
# ['Bobby', 'Jindal']
# bobbyjindal 14
# ['John', 'Kasich']
# johnkasich 15
# ['George', 'Pataki']
# georgepataki 16
# ['Rand', 'Paul']
# randpaul 17
# ['Rick', 'Perry']
# rickperry 18
# ['Marco', 'Rubio']
# marcorubio 19
# ['Rick', 'Santorum']
# ricksantorum 20
# ['Donald', 'Trump']
# donaldtrump 21
# ['Scott', 'Walker']
# scottwalker 22
# ['Tea', 'Party', 'movement']
# teapartymovement 23
# ['Legality', 'cannabis']
# legalitycannabis 24
# ['marijuana']
# marijuana 25
# ['Russia', 'Ukraine']
# russiaukraine 26
# ['Immigra']
# immigra 27
# ['illegal', 'immigra', 'united', 'states']
# illegalimmigraunitedstates 28
# ['Gun', 'law']
# gunlaw 29
# ['Gun', 'control']
# guncontrol 30
# ['Israel', 'United', 'States', 'relations']
# israelunitedstatesrelations 31
# ['Economic', 'inequality']
# economicinequality 32
# ['Income', 'inequality', 'United', 'States']
# incomeinequalityunitedstates 33
# ['Wealth', 'inequality', 'United', 'States']
# wealthinequalityunitedstates 34
# ['International', 'trade']
# internationaltrade 35
# ['Minimum', 'Wage']
# minimumwage 36
# ['Death', 'Penalty']
# deathpenalty 37
# ['Capital', 'Punishment']
# capitalpunishment 38
# ['Keystone', 'Pipeline']
# keystonepipeline 39
# ['Black', 'Lives', 'Matter']
# blacklivesmatter 40
# ['United', 'States', 'Cuba', 'Relations']
# unitedstatescubarelations 41
# ['health', 'care', 'reform']
# healthcarereform 42
# ['affordable', 'care', 'act']
# affordablecareact 43
# ['islamic', 'state']
# islamicstate 44
# ['iraq', 'war']
# iraqwar 45
# ['iran', 'nuclear', 'deal']
# irannucleardeal 46
# ['war', 'in', 'afghanistan']
# warinafghanistan 47
# ['syria']
# syria 48
# ['north', 'korea']
# northkorea 49
# ['south', 'korea']
# southkorea 50
# ['china']
# china 51
# ['guantanamo', 'bay']
# guantanamobay 52
# ['economy', 'of', 'the', 'united', 'states']
# economyoftheunitedstates 53
# ['USA', 'jobs']
# usajobs 54
# ['terrorism']
# terrorism 55
# ['immigration']
# immigration 56
# ['anchor', 'baby']
# anchorbaby 57
# ['climate', 'change']
# climatechange 58
# ['federal', 'deficit']
# federaldeficit 59
# ['internal', 'revenue', 'service']
# internalrevenueservice 60
# ['foreign', 'policy', 'united', 'states']
# foreignpolicyunitedstates 61
# ['racism', 'united', 'states']
# racismunitedstates 62
# ['Federal', 'budget', 'united', 'states']
# federalbudgetunitedstates 63
# ['tax', 'united', 'states']
# taxunitedstates 64
# ['political', 'part', 'united', 'states']
# politicalpartunitedstates 65
# ['Abortion', 'united', 'states']
# abortionunitedstates 66
# ['Pro', 'Life', 'united', 'states']
# prolifeunitedstates 67
# ['Pro', 'Choice', 'united', 'states']
# prochoiceunitedstates 68
# ['birth', 'control', 'united', 'states']
# birthcontrolunitedstates 69
# ['Planned', 'Parenthood']
# plannedparenthood 70
# ['Energy', 'united', 'states']
# energyunitedstates 71
# ['Environmental', 'issues', 'united', 'states']
# environmentalissuesunitedstates 72
# ['Labor', 'Unions', 'united', 'states']
# laborunionsunitedstates 73
# ['Marriage', 'United', 'States']
# marriageunitedstates 74
# ['illegal', 'drugs']
# illegaldrugs 75
# ['Science', 'funding']
# sciencefunding 76
# ['national', 'science', 'foundation']
# nationalsciencefoundation 77
# ['NASA']
# nasa 78
# ['Space', 'Exploration']
# spaceexploration 79
# ['baltimore', '2015']
# baltimore2015 80
# ['Freddie', 'Gray']
# freddiegray 81
# ['ferguson', 'unrest']
# fergusonunrest 82
# ['Michael', 'Brown']
# michaelbrown 83

# %%
i=6

xmin=datetime.datetime(2015,3,1)
xmax=datetime.datetime(2015,10,1)
ymin=0;ymax=4000;
# %matplotlib inline
print topics[i][2].rsplit()
ilabel=topics[i][2].rsplit()[0]
top=topics[i][1]#topic to consider for now
print top,i
data[top]['date']=map(lambda x:date_parse2(x),data[top]['vd'] )
#df[1][['tl','vd','vc']]
plt.plot_date(data[top][['date']].values,data[top][['vc']].values)
plt.xlim([xmin,xmax])
plt.ylim([ymin,ymax])
plt.show()
# Out:
# ['Jeb', 'Bush']
# jebbush 6

# %%
74
