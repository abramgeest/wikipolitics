# %%
import urllib
import pandas as pd
import numpy as np
import datetime
import string
import pymysql as mdb

# %%
maketables=False

# %%
topicsfile="/Users/abramvandergeest/Dropbox/insight_work/topic_list2011.txt"
f=open(topicsfile)
topics=f.readlines()
f.close()

# %%
afile="/Users/abramvandergeest/mysql_insightwiki_auth.txt"
a=open(afile)
passwd=a.readline().rstrip()
a.close()
host='localhost'; user='abram.ghost';db='wikidata2011'

con = mdb.connect(host, user, passwd, db)

#I should also create the  database if it doesn't exist

# %%
if maketables==True:
    #Makes topics table
    with con:
        cur = con.cursor()
        cur.execute("DROP TABLE IF EXISTS `topics`;")
        str="CREATE TABLE `topics` (`Id` INT PRIMARY KEY AUTO_INCREMENT, `topic_label` VARCHAR(64), `topic_string` VARCHAR(64));"
        cur.execute(str)
    
    #Populate topics table
    with con:
        for topic in topics:
            label="".join(topic.lower().split())
            string=topic.rstrip()
            sql="INSERT INTO `topics` (`topic_label`,`topic_string`) VALUES (%s,%s);"
            cur.execute(sql,(label,string))
        
    #Makes page_views table
    with con:
        cur = con.cursor()
        cur.execute("DROP TABLE IF EXISTS `page_views`;")
        str="CREATE TABLE `page_views` (`Id` INT PRIMARY KEY AUTO_INCREMENT, `topic_id` INT, `count` INT, `date` VARCHAR(64));"
        cur.execute(str)

# %%
def get_unzip(d,fo,fo2):
    wikiurl="http://dumps.wikimedia.org/other/pagecounts-raw/%4d/%4d-%02d/"%(d.year,d.year,d.month)
    gzfile="pagecounts-%4d%02d%02d-%02d0000.gz"%(d.year,d.month,d.day,d.hour)
    print gzfile
    fn=wikiurl+gzfile
    urllib.urlretrieve(fn,fo)
    # !gunzip -c $fo>$fo2
    return

def csv_to_reduceddf(fo2):
    allwiki=pd.read_csv(fo2,delim_whitespace=True)
    allwiki.columns=['lang','article','views','size']
    enwiki=allwiki[allwiki['lang']=='en']
    enwiki=enwiki[enwiki['size']>=50000]
    return(enwiki)

# %%
#creating a dataframe with all english pages of a large size
print "starting"
year=2011
month=12
day=21
hour=16
fo="/Users/abramvandergeest/wikidata/temp.gz"
fo2="/Users/abramvandergeest/wikidata/temp.txt"
d=datetime.datetime(year,month,day,hour)
dend=datetime.datetime(2012,2,1,17)
#dend=datetime.datetime.now()
print "end date is :",dend
dt=datetime.timedelta(days=+1)
# Out:
# starting
# end date is : 2012-02-01 17:00:00

# %%
print "entering loop"

while d<datetime.datetime(dend.year,dend.month,dend.day,dend.hour):
    try:
        get_unzip(d,fo,fo2)  #gets the gz file at wikipedia and unzips it
        print "it is unzipped"
        
        enwiki=csv_to_reduceddf(fo2) #takes the unzipped file and pairs it down and puts it into a df
        print "english entries separated"
        
        date='%4d%02d%02d%02d'%(d.year,d.month,d.day,d.hour)
        dic={}
        views=[]
        with con:
            cur = con.cursor()
            sql="SELECT `Id`,`topic_label`,`topic_string` FROM `topics`;"
            cur.execute(sql)
            for row in cur:
                tops=row[2].rstrip().split()
                twiki=enwiki[np.logical_and.reduce([enwiki['article'].str.contains(top,case=False) for top in tops ])==True]
                t=row[2].rstrip()
                dic[t]=twiki['views'].sum(axis=0)
                #print row[0],dic[t],date
                views.append([row[0],dic[t],date])
        print "pageviews sorted"
        
        with con:
            cur = con.cursor()
            for view in views:
                sql="INSERT INTO `page_views` (`topic_id`,`count`,`date`) VALUES (%s,%s,%s);"
                cur.execute(sql,view)
    
        print date
        d+=dt
    except Exception, e:    
        print "Hit an exception but we are continuing: %s",e
        d+=dt
# Out:
# entering loop
# pagecounts-20111112-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011111216
# pagecounts-20111113-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011111316
# pagecounts-20111114-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011111416
# pagecounts-20111115-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011111516
# pagecounts-20111116-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011111616
# pagecounts-20111117-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011111716
# pagecounts-20111118-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011111816
# pagecounts-20111119-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011111916
# pagecounts-20111120-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011112016
# pagecounts-20111121-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011112116
# pagecounts-20111122-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011112216
# pagecounts-20111123-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011112316
# pagecounts-20111124-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011112416
# pagecounts-20111125-160000.gz
# gunzip: /Users/abramvandergeest/wikidata/temp.gz: not in gzip format
# it is unzipped
# Hit an exception but we are continuing: %s No columns to parse from file
# pagecounts-20111126-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011112616
# pagecounts-20111127-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011112716
# pagecounts-20111128-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011112816
# pagecounts-20111129-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011112916
# pagecounts-20111130-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011113016
# pagecounts-20111201-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011120116
# pagecounts-20111202-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011120216
# pagecounts-20111203-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011120316
# pagecounts-20111204-160000.gz
# gunzip: /Users/abramvandergeest/wikidata/temp.gz: not in gzip format
# it is unzipped
# Hit an exception but we are continuing: %s No columns to parse from file
# pagecounts-20111205-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011120516
# pagecounts-20111206-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011120616
# pagecounts-20111207-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011120716
# pagecounts-20111208-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011120816
# pagecounts-20111209-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011120916
# pagecounts-20111210-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011121016
# pagecounts-20111211-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011121116
# pagecounts-20111212-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011121216
# pagecounts-20111213-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011121316
# pagecounts-20111214-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011121416
# pagecounts-20111215-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011121516
# pagecounts-20111216-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011121616
# pagecounts-20111217-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011121716
# pagecounts-20111218-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011121816
# pagecounts-20111219-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011121916
# pagecounts-20111220-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2011122016
# pagecounts-20111221-160000.gz
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-de11a8514af3> in <module>()
#       3 while d<datetime.datetime(dend.year,dend.month,dend.day,dend.hour):
#       4     try:
# ----> 5         get_unzip(d,fo,fo2)  #gets the gz file at wikipedia and unzips it
#       6         print "it is unzipped"
#       7
#
# <ipython-input-13-bbc2793121ea> in get_unzip(d, fo, fo2)
#       4     print gzfile
#       5     fn=wikiurl+gzfile
# ----> 6     urllib.urlretrieve(fn,fo)
#       7     get_ipython().system(u'gunzip -c $fo>$fo2')
#       8     return
#
# /Users/abramvandergeest/anaconda/lib/python2.7/urllib.pyc in urlretrieve(url, filename, reporthook, data, context)
#      96     else:
#      97         opener = _urlopener
# ---> 98     return opener.retrieve(url, filename, reporthook, data)
#      99 def urlcleanup():
#     100     if _urlopener:
#
# /Users/abramvandergeest/anaconda/lib/python2.7/urllib.pyc in retrieve(self, url, filename, reporthook, data)
#     271                     reporthook(blocknum, bs, size)
#     272                 while 1:
# --> 273                     block = fp.read(bs)
#     274                     if block == "":
#     275                         break
#
# /Users/abramvandergeest/anaconda/lib/python2.7/socket.pyc in read(self, size)
#     382                 # fragmentation issues on many platforms.
#     383                 try:
# --> 384                     data = self._sock.recv(left)
#     385                 except error, e:
#     386                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %% [markdown]
# pagecounts-20110310-160000.gz to pagecounts-20110315-160000.gz gz didn't exist
# pagecounts-20110303-160000.gz to pagecounts-20110305-160000.gz gz didn't exist
# pagecounts-20110625-160000.gz to pagecounts-20110627-160000.gz gz didn't exist
# pagecounts-20110610-160000.gz && pagecounts-20110612-160000.gz  gz didn't exist
# pagecounts-20110606-160000.gz  gz didn't exist
# pagecounts-20110528-160000.gz to pagecounts-20110530-160000.gz gz didn't exist
# pagecounts-20110519-160000.gz gz didn't exist
# pagecounts-20110904-160000.gz, pagecounts-20110908-160000.gz, pagecounts-20110912-160000.gz don't exist
# pagecounts-20110916-160000.gz, pagecounts-20111001-160000.gz, pagecounts-20111012-160000.gz
