# %%
import urllib
import pandas as pd
import numpy as np
import datetime
import string
import pymysql as mdb

# %%
maketables=True

# %%
topicsfile="/Users/abramvandergeest/Dropbox/insight_work/topic_list2011.txt"
f=open(topicsfile)
topics=f.readlines()
f.close()

# %%
afile="/Users/abramvandergeest/mysql_insightwiki_auth.txt"
a=open(afile)
auth=a.readlines()

con = mdb.connect(auth[0].rstrip(), auth[1].rstrip(), auth[2].rstrip(), "wikidata2011")
#con = mdb.connect('localhost', 'abram.ghost', '', 'wikidata')
####I NEED TO SET THIS TO A NON-GITHUB AUTHENTICATION LOCATION AND CHANGE PASSWORD
####DONE - Also PASSWORD HAS BEEN CHANGED

#I should also create the  database if it doesn't exist

# %%
if maketables==True:
    #Makes topics table
    with con:
        cur = con.cursor()
        cur.execute("DROP TABLE IF EXISTS `topics`;")
        str="CREATE TABLE `topics` (`Id` INT PRIMARY KEY AUTO_INCREMENT, `topic_label` VARCHAR(64), `topic_string` VARCHAR(64));"
        cur.execute(str)
    
    #Populate topics table
    with con:
        for topic in topics:
            label="".join(topic.lower().split())
            string=topic.rstrip()
            sql="INSERT INTO `topics` (`topic_label`,`topic_string`) VALUES (%s,%s);"
            cur.execute(sql,(label,string))
        
    #Makes page_views table
    with con:
        cur = con.cursor()
        cur.execute("DROP TABLE IF EXISTS `page_views`;")
        str="CREATE TABLE `page_views` (`Id` INT PRIMARY KEY AUTO_INCREMENT, `topic_id` INT, `count` INT, `date` VARCHAR(64));"
        cur.execute(str)

# %%
def get_unzip(d,fo,fo2):
    wikiurl="http://dumps.wikimedia.org/other/pagecounts-raw/%4d/%4d-%02d/"%(d.year,d.year,d.month)
    gzfile="pagecounts-%4d%02d%02d-%02d0000.gz"%(d.year,d.month,d.day,d.hour)
    print gzfile
    fn=wikiurl+gzfile
    urllib.urlretrieve(fn,fo)
    # !gunzip -c $fo>$fo2
    return

def csv_to_reduceddf(fo2):
    allwiki=pd.read_csv(fo2,delim_whitespace=True)
    allwiki.columns=['lang','article','views','size']
    enwiki=allwiki[allwiki['lang']=='en']
    enwiki=enwiki[enwiki['size']>=50000]
    return(enwiki)

# %%
#creating a dataframe with all english pages of a large size
print "starting"
year=2011
month=3
day=1
hour=16
fo="/Users/abramvandergeest/wikidata/temp.gz"
fo2="/Users/abramvandergeest/wikidata/temp.txt"
d=datetime.datetime(year,month,day,hour)
dend=datetime.datetime(2011,11,11,17)
#dend=datetime.datetime.now()
print "end date is :",dend
dt=datetime.timedelta(days=+1)
# Out:
# starting
# 2015-09-15 09:02:47.230335

# %%
print "entering loop"

while d<datetime.datetime(dend.year,dend.month,dend.day,dend.hour):
    try:
        get_unzip(d,fo,fo2)  #gets the gz file at wikipedia and unzips it
        print "it is unzipped"
        
        enwiki=csv_to_reduceddf(fo2) #takes the unzipped file and pairs it down and puts it into a df
        print "english entries separated"
        
        date='%4d%02d%02d%02d'%(d.year,d.month,d.day,d.hour)
        dic={}
        views=[]
        with con:
            cur = con.cursor()
            sql="SELECT `Id`,`topic_label`,`topic_string` FROM `topics`;"
            cur.execute(sql)
            for row in cur:
                tops=row[2].rstrip().split()
                twiki=enwiki[np.logical_and.reduce([enwiki['article'].str.contains(top,case=False) for top in tops ])==True]
                t=row[2].rstrip()
                dic[t]=twiki['views'].sum(axis=0)
                #print row[0],dic[t],date
                views.append([row[0],dic[t],date])
        print "pageviews sorted"
        
        with con:
            cur = con.cursor()
            for view in views:
                sql="INSERT INTO `page_views` (`topic_id`,`count`,`date`) VALUES (%s,%s,%s);"
                cur.execute(sql,view)
    
        print date
        d+=dt
    except Exception, e:    
        print "Hit an exception but we are continuing: %s",e
        d+=dt
# Out:
# entering loop
# pagecounts-20150709-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015070916
# pagecounts-20150710-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015071016
# pagecounts-20150711-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015071116
# pagecounts-20150712-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015071216
# pagecounts-20150713-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015071316
# pagecounts-20150714-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015071416
# pagecounts-20150715-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015071516
# pagecounts-20150716-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015071616
# pagecounts-20150717-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015071716
# pagecounts-20150718-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015071816
# pagecounts-20150719-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015071916
# pagecounts-20150720-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015072016
# pagecounts-20150721-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015072116
# pagecounts-20150722-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015072216
# pagecounts-20150723-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015072316
# pagecounts-20150724-160000.gz
# it is unzipped
# Hit an exception but we are continuing: %s Length mismatch: Expected axis has 3 elements, new values have 4 elements
# pagecounts-20150725-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015072516
# pagecounts-20150726-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015072616
# pagecounts-20150727-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015072716
# pagecounts-20150728-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015072816
# pagecounts-20150729-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015072916
# pagecounts-20150730-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015073016
# pagecounts-20150731-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015073116
# pagecounts-20150801-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015080116
# pagecounts-20150802-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015080216
# pagecounts-20150803-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015080316
# pagecounts-20150804-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015080416
# pagecounts-20150805-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015080516
# pagecounts-20150806-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015080616
# pagecounts-20150807-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015080716
# pagecounts-20150808-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015080816
# pagecounts-20150809-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015080916
# pagecounts-20150810-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015081016
# pagecounts-20150811-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015081116
# pagecounts-20150812-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015081216
# pagecounts-20150813-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015081316
# pagecounts-20150814-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015081416
# pagecounts-20150815-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015081516
# pagecounts-20150816-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015081616
# pagecounts-20150817-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015081716
# pagecounts-20150818-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015081816
# pagecounts-20150819-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015081916
# pagecounts-20150820-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015082016
# pagecounts-20150821-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015082116
# pagecounts-20150822-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015082216
# pagecounts-20150823-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015082316
# pagecounts-20150824-160000.gz
# it is unzipped
# Hit an exception but we are continuing: %s Length mismatch: Expected axis has 3 elements, new values have 4 elements
# pagecounts-20150825-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015082516
# pagecounts-20150826-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015082616
# pagecounts-20150827-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015082716
# pagecounts-20150828-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015082816
# pagecounts-20150829-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015082916
# pagecounts-20150830-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015083016
# pagecounts-20150831-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015083116
# pagecounts-20150901-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015090116
# pagecounts-20150902-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015090216
# pagecounts-20150903-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015090316
# pagecounts-20150904-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015090416
# pagecounts-20150905-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015090516
# pagecounts-20150906-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015090616
# pagecounts-20150907-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015090716
# pagecounts-20150908-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015090816
# pagecounts-20150909-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015090916
# pagecounts-20150910-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015091016
# pagecounts-20150911-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015091116
# pagecounts-20150912-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015091216
# pagecounts-20150913-160000.gz
# it is unzipped
# english entries separated
# pageviews sorted
# 2015091316
# pagecounts-20150914-160000.gz
# it is unzipped
# english entries separated
